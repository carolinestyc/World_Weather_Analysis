# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | labuan
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | shingu
# Processing Record 5 of Set 1 | bhimunipatnam
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | tchaourou
# Processing Record 8 of Set 1 | mega
# Processing Record 9 of Set 1 | port hardy
# Processing Record 10 of Set 1 | margate
# Processing Record 11 of Set 1 | vedaranniyam
# City not found. Skipping...
# Processing Record 12 of Set 1 | burica
# City not found. Skipping...
# Processing Record 13 of Set 1 | voh
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | kaitangata
# Processing Record 17 of Set 1 | moyo
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | ukiah
# Processing Record 21 of Set 1 | palimbang
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | bathsheba
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | gat
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | tongchuan
# Processing Record 34 of Set 1 | yuci
# Processing Record 35 of Set 1 | hargeysa
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | pangkalanbuun
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 1 | nalut
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | visnes
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | chokurdakh
# Processing Record 45 of Set 1 | manali
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | guerrero negro
# Processing Record 48 of Set 1 | glendive
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | noshiro
# Processing Record 2 of Set 2 | kazanskaya
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | valparaiso
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | longyan
# Processing Record 7 of Set 2 | wagrowiec
# Processing Record 8 of Set 2 | veraval
# Processing Record 9 of Set 2 | aitape
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | madimba
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | garango
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | ahipara
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | namatanai
# Processing Record 23 of Set 2 | grindavik
# Processing Record 24 of Set 2 | tura
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 2 | brae
# Processing Record 30 of Set 2 | suntar
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | lavrentiya
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | xilopolis
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | nurota
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | alikalia
# Processing Record 43 of Set 2 | kananga
# Processing Record 44 of Set 2 | tisovec
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | hobyo
# Processing Record 50 of Set 2 | meulaboh
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | hambantota
# Processing Record 3 of Set 3 | kupino
# Processing Record 4 of Set 3 | port blair
# Processing Record 5 of Set 3 | luxor
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | monte alegre
# Processing Record 8 of Set 3 | kruisfontein
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | rio do sul
# Processing Record 11 of Set 3 | clearwater
# Processing Record 12 of Set 3 | leningradskiy
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | havre-saint-pierre
# Processing Record 15 of Set 3 | lompoc
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | los llanos de aridane
# Processing Record 18 of Set 3 | rio cuarto
# Processing Record 19 of Set 3 | santiago del estero
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | hermanus
# Processing Record 22 of Set 3 | vestmannaeyjar
# Processing Record 23 of Set 3 | muravlenko
# Processing Record 24 of Set 3 | kingman
# Processing Record 25 of Set 3 | dordrecht
# Processing Record 26 of Set 3 | nizwa
# Processing Record 27 of Set 3 | tukums
# Processing Record 28 of Set 3 | boyolangu
# Processing Record 29 of Set 3 | pyay
# Processing Record 30 of Set 3 | flin flon
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | antofagasta
# Processing Record 33 of Set 3 | atuona
# Processing Record 34 of Set 3 | soria
# Processing Record 35 of Set 3 | la ronge
# Processing Record 36 of Set 3 | launceston
# Processing Record 37 of Set 3 | visim
# Processing Record 38 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | carutapera
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | sur
# Processing Record 45 of Set 3 | terney
# Processing Record 46 of Set 3 | alexandria
# Processing Record 47 of Set 3 | kupang
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | lodwar
# Processing Record 50 of Set 3 | tocopilla
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | am timan
# Processing Record 3 of Set 4 | kawalu
# Processing Record 4 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 4 | kahului
# Processing Record 6 of Set 4 | talnakh
# Processing Record 7 of Set 4 | nabire
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | olinda
# Processing Record 10 of Set 4 | nouadhibou
# Processing Record 11 of Set 4 | barrow
# Processing Record 12 of Set 4 | moron
# Processing Record 13 of Set 4 | manzhouli
# Processing Record 14 of Set 4 | bethel
# Processing Record 15 of Set 4 | podor
# Processing Record 16 of Set 4 | cabra
# Processing Record 17 of Set 4 | aklavik
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | ankazoabo
# Processing Record 20 of Set 4 | vila franca do campo
# Processing Record 21 of Set 4 | fukumitsu
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | belaya gora
# Processing Record 24 of Set 4 | chernyshevskiy
# Processing Record 25 of Set 4 | marzuq
# Processing Record 26 of Set 4 | sistranda
# Processing Record 27 of Set 4 | shkotovo-22
# City not found. Skipping...
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | hirara
# Processing Record 30 of Set 4 | sinaloa
# Processing Record 31 of Set 4 | murray bridge
# Processing Record 32 of Set 4 | haines junction
# Processing Record 33 of Set 4 | zhigansk
# Processing Record 34 of Set 4 | port macquarie
# Processing Record 35 of Set 4 | panzhihua
# Processing Record 36 of Set 4 | mount gambier
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | dyshne-vedeno
# Processing Record 40 of Set 4 | salvador
# Processing Record 41 of Set 4 | bukama
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | kirakira
# Processing Record 44 of Set 4 | quatre cocos
# Processing Record 45 of Set 4 | lakes entrance
# Processing Record 46 of Set 4 | takoradi
# Processing Record 47 of Set 4 | luganville
# Processing Record 48 of Set 4 | copiapo
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 4 | cap malheureux
# Processing Record 1 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | indiaroba
# Processing Record 6 of Set 5 | dingle
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | luchegorsk
# Processing Record 9 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 10 of Set 5 | santa maria
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | oranjestad
# Processing Record 13 of Set 5 | narasannapeta
# Processing Record 14 of Set 5 | dunedin
# Processing Record 15 of Set 5 | bang krathum
# Processing Record 16 of Set 5 | ivolginsk
# Processing Record 17 of Set 5 | tongliao
# Processing Record 18 of Set 5 | byron bay
# Processing Record 19 of Set 5 | ostrovnoy
# Processing Record 20 of Set 5 | alyangula
# Processing Record 21 of Set 5 | faanui
# Processing Record 22 of Set 5 | bada
# Processing Record 23 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | mayskiy
# Processing Record 27 of Set 5 | dhidhdhoo
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | tahe
# Processing Record 30 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 5 | alterosa
# Processing Record 32 of Set 5 | manubul
# Processing Record 33 of Set 5 | xiongzhou
# Processing Record 34 of Set 5 | inuvik
# Processing Record 35 of Set 5 | dongsheng
# Processing Record 36 of Set 5 | kaoma
# Processing Record 37 of Set 5 | mayo
# Processing Record 38 of Set 5 | kodiak
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | bandarbeyla
# Processing Record 41 of Set 5 | pietarsaari
# Processing Record 42 of Set 5 | sao filipe
# Processing Record 43 of Set 5 | japura
# Processing Record 44 of Set 5 | toamasina
# Processing Record 45 of Set 5 | coquimbo
# Processing Record 46 of Set 5 | sosua
# Processing Record 47 of Set 5 | narrabri
# Processing Record 48 of Set 5 | makung
# City not found. Skipping...
# Processing Record 49 of Set 5 | wanaka
# Processing Record 50 of Set 5 | porto novo
# Processing Record 1 of Set 6 | khotyn
# Processing Record 2 of Set 6 | the valley
# Processing Record 3 of Set 6 | north bend
# Processing Record 4 of Set 6 | erzin
# Processing Record 5 of Set 6 | aksu
# Processing Record 6 of Set 6 | cherskiy
# Processing Record 7 of Set 6 | fortuna
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | severo-kurilsk
# Processing Record 10 of Set 6 | bokoro
# Processing Record 11 of Set 6 | qasigiannguit
# Processing Record 12 of Set 6 | sarangani
# Processing Record 13 of Set 6 | bilibino
# Processing Record 14 of Set 6 | desur
# Processing Record 15 of Set 6 | asyut
# Processing Record 16 of Set 6 | willowmore
# Processing Record 17 of Set 6 | kununurra
# Processing Record 18 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 6 | manacapuru
# Processing Record 20 of Set 6 | rosetta
# Processing Record 21 of Set 6 | makhachkala
# Processing Record 22 of Set 6 | hun
# Processing Record 23 of Set 6 | urdoma
# Processing Record 24 of Set 6 | teguldet
# Processing Record 25 of Set 6 | honghu
# Processing Record 26 of Set 6 | yulara
# Processing Record 27 of Set 6 | isangel
# Processing Record 28 of Set 6 | tessalit
# Processing Record 29 of Set 6 | puerto baquerizo moreno
# Processing Record 30 of Set 6 | inta
# Processing Record 31 of Set 6 | praia
# Processing Record 32 of Set 6 | sri aman
# Processing Record 33 of Set 6 | gohpur
# Processing Record 34 of Set 6 | new plymouth
# Processing Record 35 of Set 6 | te anau
# Processing Record 36 of Set 6 | kalmunai
# Processing Record 37 of Set 6 | skagen
# Processing Record 38 of Set 6 | klaksvik
# Processing Record 39 of Set 6 | san quintin
# Processing Record 40 of Set 6 | miles city
# Processing Record 41 of Set 6 | moranbah
# Processing Record 42 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 6 | kasongo-lunda
# Processing Record 44 of Set 6 | samana
# Processing Record 45 of Set 6 | roald
# Processing Record 46 of Set 6 | srednekolymsk
# Processing Record 47 of Set 6 | sobolevo
# Processing Record 48 of Set 6 | ouesso
# Processing Record 49 of Set 6 | nouakchott
# Processing Record 50 of Set 6 | sinazongwe
# Processing Record 1 of Set 7 | sioux lookout
# Processing Record 2 of Set 7 | mopti
# Processing Record 3 of Set 7 | linxia
# Processing Record 4 of Set 7 | verkh-usugli
# Processing Record 5 of Set 7 | solhan
# Processing Record 6 of Set 7 | kudahuvadhoo
# Processing Record 7 of Set 7 | luanda
# Processing Record 8 of Set 7 | sola
# Processing Record 9 of Set 7 | devyatka
# City not found. Skipping...
# Processing Record 10 of Set 7 | ayan
# Processing Record 11 of Set 7 | hutchinson
# Processing Record 12 of Set 7 | moindou
# Processing Record 13 of Set 7 | lagarto
# Processing Record 14 of Set 7 | proletarsk
# Processing Record 15 of Set 7 | atikokan
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | ulladulla
# Processing Record 18 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 7 | itarema
# Processing Record 20 of Set 7 | melton
# Processing Record 21 of Set 7 | polunochnoye
# Processing Record 22 of Set 7 | tilichiki
# Processing Record 23 of Set 7 | mahebourg
# Processing Record 24 of Set 7 | higashine
# Processing Record 25 of Set 7 | saldanha
# Processing Record 26 of Set 7 | ozinki
# Processing Record 27 of Set 7 | riviere-au-renard
# Processing Record 28 of Set 7 | pokosnoye
# Processing Record 29 of Set 7 | ghanzi
# Processing Record 30 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 31 of Set 7 | farrukhnagar
# Processing Record 32 of Set 7 | kavieng
# Processing Record 33 of Set 7 | sao felix do xingu
# Processing Record 34 of Set 7 | south lake tahoe
# Processing Record 35 of Set 7 | floro
# Processing Record 36 of Set 7 | rennes
# Processing Record 37 of Set 7 | enniscorthy
# Processing Record 38 of Set 7 | igarka
# Processing Record 39 of Set 7 | chaman
# Processing Record 40 of Set 7 | vila velha
# Processing Record 41 of Set 7 | belton
# Processing Record 42 of Set 7 | narsaq
# Processing Record 43 of Set 7 | inverell
# Processing Record 44 of Set 7 | bentiu
# Processing Record 45 of Set 7 | lazaro cardenas
# Processing Record 46 of Set 7 | honningsvag
# Processing Record 47 of Set 7 | balikpapan
# Processing Record 48 of Set 7 | alice springs
# Processing Record 49 of Set 7 | anadyr
# Processing Record 50 of Set 7 | nanortalik
# Processing Record 1 of Set 8 | novikovo
# Processing Record 2 of Set 8 | prince rupert
# Processing Record 3 of Set 8 | krasnoselkup
# Processing Record 4 of Set 8 | warwick
# Processing Record 5 of Set 8 | nyurba
# Processing Record 6 of Set 8 | havoysund
# Processing Record 7 of Set 8 | petatlan
# Processing Record 8 of Set 8 | kavaratti
# Processing Record 9 of Set 8 | broome
# Processing Record 10 of Set 8 | longyearbyen
# Processing Record 11 of Set 8 | lianzhou
# Processing Record 12 of Set 8 | nancha
# Processing Record 13 of Set 8 | fort nelson
# Processing Record 14 of Set 8 | pandamatenga
# Processing Record 15 of Set 8 | chipata
# Processing Record 16 of Set 8 | beaufort
# Processing Record 17 of Set 8 | waterloo
# Processing Record 18 of Set 8 | ios
# Processing Record 19 of Set 8 | egvekinot
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | kirovo-chepetsk
# Processing Record 22 of Set 8 | bac lieu
# Processing Record 23 of Set 8 | mount isa
# Processing Record 24 of Set 8 | nanning
# Processing Record 25 of Set 8 | avera
# Processing Record 26 of Set 8 | keffi
# Processing Record 27 of Set 8 | fare
# Processing Record 28 of Set 8 | pajan
# Processing Record 29 of Set 8 | whitianga
# Processing Record 30 of Set 8 | kailua
# Processing Record 31 of Set 8 | colac
# Processing Record 32 of Set 8 | mocuba
# Processing Record 33 of Set 8 | tsukumi
# Processing Record 34 of Set 8 | bilma
# Processing Record 35 of Set 8 | norman wells
# Processing Record 36 of Set 8 | aykhal
# Processing Record 37 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 8 | portland
# Processing Record 39 of Set 8 | mayumba
# Processing Record 40 of Set 8 | altus
# Processing Record 41 of Set 8 | barhi
# Processing Record 42 of Set 8 | tome
# Processing Record 43 of Set 8 | husavik
# Processing Record 44 of Set 8 | yining
# Processing Record 45 of Set 8 | son la
# Processing Record 46 of Set 8 | mar del plata
# Processing Record 47 of Set 8 | nevel
# Processing Record 48 of Set 8 | araguacu
# Processing Record 49 of Set 8 | seoul
# Processing Record 50 of Set 8 | paramonga
# Processing Record 1 of Set 9 | vanimo
# Processing Record 2 of Set 9 | sudislavl
# Processing Record 3 of Set 9 | cururupu
# Processing Record 4 of Set 9 | bagula
# Processing Record 5 of Set 9 | bukachacha
# Processing Record 6 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 9 | la orilla
# Processing Record 8 of Set 9 | powell
# Processing Record 9 of Set 9 | birjand
# Processing Record 10 of Set 9 | sompeta
# Processing Record 11 of Set 9 | port lincoln
# Processing Record 12 of Set 9 | rakek
# Processing Record 13 of Set 9 | grand-santi
# Processing Record 14 of Set 9 | muroto
# Processing Record 15 of Set 9 | huarmey
# Processing Record 16 of Set 9 | alofi
# Processing Record 17 of Set 9 | sovetskiy
# Processing Record 18 of Set 9 | sarahan
# Processing Record 19 of Set 9 | foshan
# Processing Record 20 of Set 9 | lata
# Processing Record 21 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 9 | ubinskoye
# Processing Record 23 of Set 9 | mandera
# Processing Record 24 of Set 9 | saint-georges
# Processing Record 25 of Set 9 | pouembout
# Processing Record 26 of Set 9 | ilo
# Processing Record 27 of Set 9 | boden
# Processing Record 28 of Set 9 | buraydah
# Processing Record 29 of Set 9 | dongobesh
# Processing Record 30 of Set 9 | kandrian
# Processing Record 31 of Set 9 | storforshei
# Processing Record 32 of Set 9 | huilong
# Processing Record 33 of Set 9 | chiredzi
# Processing Record 34 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 9 | walvis bay
# Processing Record 36 of Set 9 | henderson
# Processing Record 37 of Set 9 | butembo
# Processing Record 38 of Set 9 | college
# Processing Record 39 of Set 9 | grand gaube
# Processing Record 40 of Set 9 | pochutla
# Processing Record 41 of Set 9 | mantua
# Processing Record 42 of Set 9 | riviere-du-loup
# Processing Record 43 of Set 9 | burns lake
# Processing Record 44 of Set 9 | manaus
# Processing Record 45 of Set 9 | luwuk
# Processing Record 46 of Set 9 | maroslele
# Processing Record 47 of Set 9 | alblasserdam
# Processing Record 48 of Set 9 | puerto escondido
# Processing Record 49 of Set 9 | kaohsiung
# Processing Record 50 of Set 9 | gore
# Processing Record 1 of Set 10 | bosaso
# Processing Record 2 of Set 10 | tatishchevo
# Processing Record 3 of Set 10 | san rafael
# Processing Record 4 of Set 10 | hami
# Processing Record 5 of Set 10 | hemnesberget
# Processing Record 6 of Set 10 | lagoa
# Processing Record 7 of Set 10 | dubbo
# Processing Record 8 of Set 10 | palasa
# Processing Record 9 of Set 10 | katsuura
# Processing Record 10 of Set 10 | olafsvik
# Processing Record 11 of Set 10 | mehamn
# Processing Record 12 of Set 10 | bengkulu
# Processing Record 13 of Set 10 | krasnoye
# Processing Record 14 of Set 10 | menongue
# Processing Record 15 of Set 10 | sao miguel do araguaia
# Processing Record 16 of Set 10 | goderich
# Processing Record 17 of Set 10 | ucluelet
# Processing Record 18 of Set 10 | tezu
# Processing Record 19 of Set 10 | sisimiut
# Processing Record 20 of Set 10 | balaipungut
# Processing Record 21 of Set 10 | talara
# Processing Record 22 of Set 10 | natal
# Processing Record 23 of Set 10 | ponta delgada
# Processing Record 24 of Set 10 | marieville
# Processing Record 25 of Set 10 | mapiri
# Processing Record 26 of Set 10 | pangnirtung
# Processing Record 27 of Set 10 | geraldton
# Processing Record 28 of Set 10 | senanga
# Processing Record 29 of Set 10 | laguna
# Processing Record 30 of Set 10 | bereda
# Processing Record 31 of Set 10 | altay
# Processing Record 32 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 34 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 10 | cabedelo
# Processing Record 36 of Set 10 | rio tercero
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | vikarabad
# Processing Record 39 of Set 10 | vila
# Processing Record 40 of Set 10 | malpe
# Processing Record 41 of Set 10 | kosh-agach
# Processing Record 42 of Set 10 | acarau
# Processing Record 43 of Set 10 | chara
# Processing Record 44 of Set 10 | denpasar
# Processing Record 45 of Set 10 | maralal
# Processing Record 46 of Set 10 | ekhabi
# Processing Record 47 of Set 10 | saint-joseph
# Processing Record 48 of Set 10 | tacna
# Processing Record 49 of Set 10 | borogontsy
# Processing Record 50 of Set 10 | naze
# Processing Record 1 of Set 11 | beloha
# Processing Record 2 of Set 11 | nhulunbuy
# Processing Record 3 of Set 11 | oktyabrskoye
# Processing Record 4 of Set 11 | kortkeros
# Processing Record 5 of Set 11 | magistralnyy
# Processing Record 6 of Set 11 | vestmanna
# Processing Record 7 of Set 11 | honiara
# Processing Record 8 of Set 11 | grand-lahou
# Processing Record 9 of Set 11 | antequera
# Processing Record 10 of Set 11 | novaya bryan
# Processing Record 11 of Set 11 | dubovka
# Processing Record 12 of Set 11 | artyom
# Processing Record 13 of Set 11 | dogondoutchi
# Processing Record 14 of Set 11 | amapa
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | ancud
# Processing Record 17 of Set 11 | taoudenni
# Processing Record 18 of Set 11 | bend
# Processing Record 19 of Set 11 | beyneu
# Processing Record 20 of Set 11 | araucaria
# Processing Record 21 of Set 11 | villa maria
# Processing Record 22 of Set 11 | nara
# Processing Record 23 of Set 11 | rocha
# Processing Record 24 of Set 11 | laredo
# Processing Record 25 of Set 11 | nerchinskiy zavod
# Processing Record 26 of Set 11 | port antonio
# Processing Record 27 of Set 11 | acapulco
# Processing Record 28 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 11 | raudeberg
# Processing Record 30 of Set 11 | touros
# Processing Record 31 of Set 11 | buala
# Processing Record 32 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 11 | berbera
# Processing Record 34 of Set 11 | baruun-urt
# Processing Record 35 of Set 11 | wajir
# Processing Record 36 of Set 11 | dauphin
# Processing Record 37 of Set 11 | youkounkoun
# Processing Record 38 of Set 11 | necochea
# Processing Record 39 of Set 11 | coihaique
# Processing Record 40 of Set 11 | jiexiu
# Processing Record 41 of Set 11 | porto walter
# Processing Record 42 of Set 11 | gushikawa
# Processing Record 43 of Set 11 | perth
# Processing Record 44 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 11 | sharjah
# Processing Record 46 of Set 11 | preobrazheniye
# Processing Record 47 of Set 11 | christchurch
# Processing Record 48 of Set 11 | oudtshoorn
# Processing Record 49 of Set 11 | iqaluit
# Processing Record 50 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | ozuluama
# Processing Record 2 of Set 12 | naifaru
# Processing Record 3 of Set 12 | tabas
# Processing Record 4 of Set 12 | lisala
# Processing Record 5 of Set 12 | marakkanam
# Processing Record 6 of Set 12 | grivenskaya
# Processing Record 7 of Set 12 | bud
# Processing Record 8 of Set 12 | comodoro rivadavia
# Processing Record 9 of Set 12 | miyako
# Processing Record 10 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 12 | nuuk
# Processing Record 12 of Set 12 | salym
# Processing Record 13 of Set 12 | varhaug
# Processing Record 14 of Set 12 | half moon bay
# Processing Record 15 of Set 12 | atherton
# Processing Record 16 of Set 12 | myrtle beach
# Processing Record 17 of Set 12 | naryan-mar
# Processing Record 18 of Set 12 | tezpur
# Processing Record 19 of Set 12 | kyra
# Processing Record 20 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 21 of Set 12 | gao
# Processing Record 22 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 23 of Set 12 | vao
# Processing Record 24 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 12 | sinnamary
# Processing Record 26 of Set 12 | roseburg
# Processing Record 27 of Set 12 | sao joao da barra
# Processing Record 28 of Set 12 | richards bay
# Processing Record 29 of Set 12 | pitimbu
# Processing Record 30 of Set 12 | poum
# Processing Record 31 of Set 12 | dukat
# Processing Record 32 of Set 12 | bunia
# Processing Record 33 of Set 12 | yar-sale
# Processing Record 34 of Set 12 | joensuu
# Processing Record 35 of Set 12 | tomari
# Processing Record 36 of Set 12 | hofn
# Processing Record 37 of Set 12 | bhatkal
# Processing Record 38 of Set 12 | aksarka
# Processing Record 39 of Set 12 | nome
# Processing Record 40 of Set 12 | devils lake
# Processing Record 41 of Set 12 | sretensk
# Processing Record 42 of Set 12 | nioro
# Processing Record 43 of Set 12 | taytay
# Processing Record 44 of Set 12 | senneterre
# Processing Record 45 of Set 12 | letychiv
# Processing Record 46 of Set 12 | sabang
# Processing Record 47 of Set 12 | jinchang
# Processing Record 48 of Set 12 | rochegda
# Processing Record 49 of Set 12 | santa rosa
# Processing Record 50 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 13 | ahome
# Processing Record 2 of Set 13 | saint anthony
# Processing Record 3 of Set 13 | zarubino
# Processing Record 4 of Set 13 | agdas
# Processing Record 5 of Set 13 | tuy hoa
# Processing Record 6 of Set 13 | mackenzie
# Processing Record 7 of Set 13 | saint-pierre
# Processing Record 8 of Set 13 | nanfeng
# Processing Record 9 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 10 of Set 13 | lorengau
# Processing Record 11 of Set 13 | amahai
# Processing Record 12 of Set 13 | adrar
# Processing Record 13 of Set 13 | lahan
# Processing Record 14 of Set 13 | yumen
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | mount pleasant
# Processing Record 17 of Set 13 | abu samrah
# Processing Record 18 of Set 13 | dinar
# Processing Record 19 of Set 13 | alexander city
# Processing Record 20 of Set 13 | leh
# Processing Record 21 of Set 13 | meiktila
# Processing Record 22 of Set 13 | ritchie
# Processing Record 23 of Set 13 | biltine
# Processing Record 24 of Set 13 | hornepayne
# Processing Record 25 of Set 13 | garden city
# Processing Record 26 of Set 13 | porto franco
# Processing Record 27 of Set 13 | soyo
# Processing Record 28 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 30 of Set 13 | hokitika
# Processing Record 31 of Set 13 | wagar
# Processing Record 32 of Set 13 | xining
# Processing Record 33 of Set 13 | nishihara
# Processing Record 34 of Set 13 | divnogorsk
# Processing Record 35 of Set 13 | grenaa
# Processing Record 36 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 13 | garowe
# Processing Record 38 of Set 13 | englehart
# Processing Record 39 of Set 13 | pushkino
# Processing Record 40 of Set 13 | coahuayana
# Processing Record 41 of Set 13 | broken hill
# Processing Record 42 of Set 13 | belyy yar
# Processing Record 43 of Set 13 | chontalpa
# Processing Record 44 of Set 13 | khor
# Processing Record 45 of Set 13 | manono
# Processing Record 46 of Set 13 | qandala
# Processing Record 47 of Set 13 | caborca
# Processing Record 48 of Set 13 | dalby
# Processing Record 49 of Set 13 | zeya
# Processing Record 50 of Set 13 | aurillac
# Processing Record 1 of Set 14 | nkowakowa
# Processing Record 2 of Set 14 | tecoanapa
# Processing Record 3 of Set 14 | kismayo
# Processing Record 4 of Set 14 | mandalgovi
# Processing Record 5 of Set 14 | ceyhan
# Processing Record 6 of Set 14 | namtsy
# Processing Record 7 of Set 14 | odessa
# Processing Record 8 of Set 14 | porto-vecchio
# Processing Record 9 of Set 14 | karratha
# Processing Record 10 of Set 14 | kuala selangor
# Processing Record 11 of Set 14 | kargil
# Processing Record 12 of Set 14 | komsomolskiy
# Processing Record 13 of Set 14 | we
# City not found. Skipping...
# Processing Record 14 of Set 14 | akdepe
# Processing Record 15 of Set 14 | hwange
# Processing Record 16 of Set 14 | krasnovishersk
# Processing Record 17 of Set 14 | orange
# Processing Record 18 of Set 14 | tommot
# Processing Record 19 of Set 14 | formosa do rio preto
# Processing Record 20 of Set 14 | goulburn
# Processing Record 21 of Set 14 | dzhankoy
# Processing Record 22 of Set 14 | petropavl
# Processing Record 23 of Set 14 | pisco
# Processing Record 24 of Set 14 | vastseliina
# Processing Record 25 of Set 14 | narodychi
# Processing Record 26 of Set 14 | talcahuano
# Processing Record 27 of Set 14 | viedma
# Processing Record 28 of Set 14 | mbandaka
# Processing Record 29 of Set 14 | goksun
# Processing Record 30 of Set 14 | victor harbor
# Processing Record 31 of Set 14 | ulaanbaatar
# Processing Record 32 of Set 14 | plettenberg bay
# Processing Record 33 of Set 14 | santa cruz
# Processing Record 34 of Set 14 | boyarka
# Processing Record 35 of Set 14 | poya
# Processing Record 36 of Set 14 | den helder
# Processing Record 37 of Set 14 | yaqui
# Processing Record 38 of Set 14 | utica
# Processing Record 39 of Set 14 | fakel
# Processing Record 40 of Set 14 | yacuiba
# Processing Record 41 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 42 of Set 14 | worthington
# Processing Record 43 of Set 14 | wladyslawowo
# Processing Record 44 of Set 14 | tarancon
# Processing Record 45 of Set 14 | xinxiang
# Processing Record 46 of Set 14 | whitehorse
# Processing Record 47 of Set 14 | bowen
# Processing Record 48 of Set 14 | catia la mar
# Processing Record 49 of Set 14 | halmstad
# Processing Record 50 of Set 14 | alta floresta
# Processing Record 1 of Set 15 | robertsport
# Processing Record 2 of Set 15 | alibag
# Processing Record 3 of Set 15 | sultanpur
# Processing Record 4 of Set 15 | havelock
# Processing Record 5 of Set 15 | amalapuram
# Processing Record 6 of Set 15 | kasempa
# Processing Record 7 of Set 15 | la fria
# Processing Record 8 of Set 15 | yarim
# Processing Record 9 of Set 15 | tucuman
# Processing Record 10 of Set 15 | pacific grove
# Processing Record 11 of Set 15 | rio gallegos
# Processing Record 12 of Set 15 | okato
# Processing Record 13 of Set 15 | nago
# Processing Record 14 of Set 15 | boralday
# Processing Record 15 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 16 of Set 15 | marsh harbour
# Processing Record 17 of Set 15 | puerto carreno
# Processing Record 18 of Set 15 | ngunguru
# Processing Record 19 of Set 15 | ust-kuyga
# Processing Record 20 of Set 15 | khowst
# Processing Record 21 of Set 15 | gaogou
# Processing Record 22 of Set 15 | palmer
# Processing Record 23 of Set 15 | seguela
# Processing Record 24 of Set 15 | ilmajoki
# Processing Record 25 of Set 15 | enshi
# Processing Record 26 of Set 15 | hella
# Processing Record 27 of Set 15 | san jose
# Processing Record 28 of Set 15 | barra do corda
# Processing Record 29 of Set 15 | xuanhua
# Processing Record 30 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 15 | bida
# Processing Record 32 of Set 15 | estacion coahuila
# Processing Record 33 of Set 15 | eskil
# Processing Record 34 of Set 15 | kuandian
# Processing Record 35 of Set 15 | hoparta
# City not found. Skipping...
# Processing Record 36 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 15 | tandil
# Processing Record 38 of Set 15 | puri
# Processing Record 39 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 40 of Set 15 | llangefni
# Processing Record 41 of Set 15 | mwingi
# Processing Record 42 of Set 15 | seymchan
# Processing Record 43 of Set 15 | paka
# Processing Record 44 of Set 15 | gwadar
# Processing Record 45 of Set 15 | codrington
# Processing Record 46 of Set 15 | viseu
# Processing Record 47 of Set 15 | zatoka
# Processing Record 48 of Set 15 | oksfjord
# Processing Record 49 of Set 15 | tomatlan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    New Norfolk -42.7826  147.0587     62.10        69          94
# 1         Labuan   5.2767  115.2417     78.96        88         100
# 2        Rikitea -23.1203 -134.9692     78.51        71          74
# 3         Shingu  33.7333  135.9833     45.91        85         100
# 4  Bhimunipatnam  17.8833   83.4333     67.51        63           7
# 5     Bredasdorp -34.5322   20.0403     65.28        80          96
# 6      Tchaourou   8.8865    2.5975     85.44        35          67
# 7           Mega   4.0500   38.3000     64.38        32          50
# 8     Port Hardy  50.6996 -127.4199     49.75        65         100
# 9        Margate  51.3813    1.3862     49.96        88         100
#
#    Wind Speed Country Current Description
# 0        2.37      AU     overcast clouds
# 1        8.12      MY     overcast clouds
# 2       12.59      PF          light rain
# 3        6.40      JP     overcast clouds
# 4        5.35      IN           clear sky
# 5       14.76      ZA     overcast clouds
# 6        3.91      BJ       broken clouds
# 7        6.49      ET    scattered clouds
# 8        5.79      CA     overcast clouds
# 9       11.01      GB          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    New Norfolk      AU -42.7826  147.0587     62.10        69          94
# 1         Labuan      MY   5.2767  115.2417     78.96        88         100
# 2        Rikitea      PF -23.1203 -134.9692     78.51        71          74
# 3         Shingu      JP  33.7333  135.9833     45.91        85         100
# 4  Bhimunipatnam      IN  17.8833   83.4333     67.51        63           7
#
#    Wind Speed Current Description
# 0        2.37     overcast clouds
# 1        8.12     overcast clouds
# 2       12.59          light rain
# 3        6.40     overcast clouds
# 4        5.35           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
